# %% [markdown]
# # TUTORIAL SQL
#
# ## ¿Qué es SQL?
#
# 1. SQL son las siglas de Structured Query Language
# 2. SQL le permite acceder y manipular bases de datos
# 3. SQL se convirtió en un estándar del American National Standards Institute (ANSI) en 1986 y de la Organización Internacional de Normalización (ISO) en 1987.
#
# ## ¿Qué puede hacer SQL?
#
# - SQL puede ejecutar consultas en una base de datos
# - SQL puede recuperar datos de una base de datos
# - SQL puede insertar registros en una base de datos
# - SQL puede actualizar registros en una base de datos
# - SQL puede eliminar registros de una base de datos
# - SQL puede crear nuevas bases de datos
# - SQL puede crear nuevas tablas en una base de datos
# - SQL puede crear procedimientos almacenados en una base de datos
# - SQL puede crear vistas en una base de datos
# - SQL puede establecer permisos en tablas, procedimientos y vistas
#
# ## Uso de SQL en su sitio web
#
# > Para crear un sitio web que muestre datos de una base de datos, necesitará:
# >
# > > Un programa de base de datos RDBMS (es decir, MS Access, SQL Server, MySQL) Para usar un lenguaje de scripting del lado del servidor, como PHP o ASP
# > >
# > > > Para usar SQL para obtener los datos que desea Para usar HTML / CSS para diseñar la página
#
# # Enlace a TUTORIAL SQL
#
# [W3SCHOLLS](https://www.w3schools.com/sql/default.asp)
#
# # TIEMPO DIVERTIDO
#
# ![1](https://lol24.ee/public/pics/264043/264043909_0.gif)![2](https://www.mapsnbags.com/wp-content/uploads/2018/11/funny-travel-meme-girl-running.jpg)
#
# ```
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>An Unordered HTML List</h2>
#
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>
#
# <h2>An Ordered HTML List</h2>
#
# <ol>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ol>
#
# </body>
# </html>
# ```
#
# # MESA
#
# Identificación del cliente | Nombre del cliente | Nombre de contacto | Dirección | Ciudad | Código postal | País
# --- | --- | --- | --- | --- | --- | ---
# 1 | Alfredo | Maria | Obere Str.57 | Berlina | 12209 | Alemania
# 2 | Anna | Anna | Calle Lavada 6 | México | 05021 | México
# 3 | Antonio | Antonio | Mataderos 12 | México | 05023 | México
